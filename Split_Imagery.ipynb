# %%
import os, gdal

# %%
in_path = "C:/Users/Emily/Documents/Fall_2020/ML_DS/Sample_Sentinel/"
input_filename = "Sample_Bing_1.png"

# %%
out_path = 'C:/Users/Emily/Documents/Fall_2020/ML_DS/Sample_Sentinel/Sample_Tile_image/'
output_filename = 'tile_'

# %%
tile_size_x = 10
tile_size_y = 10

# %%
ds = gdal.Open(in_path + input_filename)
band = ds.GetRasterBand(1)
xsize = band.XSize
ysize = band.YSize

# %%
for i in range(0, xsize, tile_size_x):
    for j in range(0, ysize, tile_size_y):
        com_string = "gdal_translate -of GTIFF -srcwin " + str(i)+ ", " + str(j) + ", " + str(tile_size_x) + ", " + str(tile_size_y) + " " + str(in_path) + str(input_filename) + " " + str(out_path) + str(output_filename) + str(i) + "_" + str(j) + ".tif"
        os.system(com_string)

# %%
from PIL import Image
from sklearn.feature_extraction import image

# %%
f = Image.open("Sample_Bing_1.png")

# %%
width, height = f.size
print (width, height)
# Out:
# 1857 699

# %%
im1 = Image.Image.split(f)

# %%
split1 = im1[0]
split1 = split1.save("Split1.png")
split2 = im1[1]
split2 = split2.save("Split2.png")
split3 = im1[2]
split3 = split3.save("Split3.png")

# %%
import image_slicer

# %%
image_slicer.slice("Split1.png", 5000)
# Out:
# (<Tile #1 - Split1_01_01.png>,
#  <Tile #2 - Split1_01_02.png>,
#  <Tile #3 - Split1_01_03.png>,
#  <Tile #4 - Split1_01_04.png>,
#  <Tile #5 - Split1_01_05.png>,
#  <Tile #6 - Split1_01_06.png>,
#  <Tile #7 - Split1_01_07.png>,
#  <Tile #8 - Split1_01_08.png>,
#  <Tile #9 - Split1_01_09.png>,
#  <Tile #10 - Split1_01_10.png>,
#  <Tile #11 - Split1_01_11.png>,
#  <Tile #12 - Split1_01_12.png>,
#  <Tile #13 - Split1_01_13.png>,
#  <Tile #14 - Split1_01_14.png>,
#  <Tile #15 - Split1_01_15.png>,
#  <Tile #16 - Split1_01_16.png>,
#  <Tile #17 - Split1_01_17.png>,
#  <Tile #18 - Split1_01_18.png>,
#  <Tile #19 - Split1_01_19.png>,
#  <Tile #20 - Split1_01_20.png>,
#  <Tile #21 - Split1_01_21.png>,
#  <Tile #22 - Split1_01_22.png>,
#  <Tile #23 - Split1_01_23.png>,
#  <Tile #24 - Split1_01_24.png>,
#  <Tile #25 - Split1_01_25.png>,
#  <Tile #26 - Split1_01_26.png>,
#  <Tile #27 - Split1_01_27.png>,
#  <Tile #28 - Split1_01_28.png>,
#  <Tile #29 - Split1_01_29.png>,
# ...
